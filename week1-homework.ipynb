# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
df = pd.read_csv("/home/phagun-jain/Downloads/housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
sh = df.shape
print(f"no of columns: {sh[1]}")
# Out:
# no of columns: 10

# %%
df.isnull()
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.ocean_proximity.nunique()
# Out:
# 5

# %%
df.median_house_value.mean()
# Out:
# 206855.81690891474

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.groupby('ocean_proximity').median_house_value.mean()
# Out:
# ocean_proximity
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# Name: median_house_value, dtype: float64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1873184/1360717439.py in ?()
# ----> 1 df.set_index('a')
#
# ~/anaconda3/envs/ml-zoomcamp/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['a'] are in the columns"

# %%
df.total_bedrooms.mean()
# Out:
# 537.8705525375618

# %%
df.total_bedrooms.describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df.total_bedrooms.isnull().sum()
# Out:
# 207

# %%
df2 = df["total_bedrooms"].fillna(538)

# %%
df2.isnull().sum()
# Out:
# 0

# %%
df2.mean()
# Out:
# 537.8718507751938

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.groupby('ocean_proximity').describe()
# Out:
#                 longitude                                                 \
#                     count        mean       std     min     25%      50%
# ocean_proximity
# <1H OCEAN          9136.0 -118.847766  1.588888 -124.14 -118.50 -118.275
# INLAND             6551.0 -119.732990  1.900950 -123.73 -121.35 -120.000
# ISLAND                5.0 -118.354000  0.070569 -118.48 -118.33 -118.320
# NEAR BAY           2290.0 -122.260694  0.147004 -122.59 -122.41 -122.250
# NEAR OCEAN         2658.0 -119.332555  2.327307 -124.35 -122.02 -118.260
#
#                                   latitude             ... median_income  \
#                       75%     max    count       mean  ...           75%
# ocean_proximity                                        ...
# <1H OCEAN       -118.0000 -116.62   9136.0  34.560577  ...      5.180500
# INLAND          -117.8400 -114.31   6551.0  36.731829  ...      3.961500
# ISLAND          -118.3200 -118.32      5.0  33.358000  ...      2.833300
# ...

# %%
df3  = df[['total_rooms','median_income','population' ]]

# %%
df3
# Out:
#        total_rooms  median_income  population
# 0            880.0         8.3252       322.0
# 1           7099.0         8.3014      2401.0
# 2           1467.0         7.2574       496.0
# 3           1274.0         5.6431       558.0
# 4           1627.0         3.8462       565.0
# ...            ...            ...         ...
# 20635       1665.0         1.5603       845.0
# 20636        697.0         2.5568       356.0
# 20637       2254.0         1.7000      1007.0
# 20638       1860.0         1.8672       741.0
# 20639       2785.0         2.3886      1387.0
#
# [20640 rows x 3 columns]

# %%
df3.total_rooms.values
df3.total_rooms.values.size
# Out:
# 20640

# %%
df3.median_income.values
df3.median_income.values.size
# Out:
# 20640

# %%
df3.population.values
df3.population.values.size
# Out:
# 20640

# %%
X = df3.values
X
# Out:
# array([[8.8000e+02, 8.3252e+00, 3.2200e+02],
#        [7.0990e+03, 8.3014e+00, 2.4010e+03],
#        [1.4670e+03, 7.2574e+00, 4.9600e+02],
#        ...,
#        [2.2540e+03, 1.7000e+00, 1.0070e+03],
#        [1.8600e+03, 1.8672e+00, 7.4100e+02],
#        [2.7850e+03, 2.3886e+00, 1.3870e+03]])

# %%
XTX = X.dot(X.T)
XTX
# Out:
# array([[  878153.30895504,  7020311.11081528,  1450732.41930648, ...,
#          2307788.15284   ,  1875417.54481344,  2897433.88557272],
#        [ 7020311.11081528, 56160670.91324196, 11605189.24658036, ...,
#         18418967.11238   , 14983296.50037408, 23100921.82872404],
#        [ 1450732.41930648, 11605189.24658036,  2398157.66985476, ...,
#          3806102.33758   ,  3096169.55101728,  4773564.33502564],
#        ...,
#        [ 2307788.15284   , 18418967.11238   ,  3806102.33758   , ...,
#          6094567.89      ,  4938630.17424   ,  7674103.06062   ],
#        [ 1875417.54481344, 14983296.50037408,  3096169.55101728, ...,
#          4938630.17424   ,  4008684.48643584,  6207871.45999392],
#        [ 2897433.88557272, 23100921.82872404,  4773564.33502564, ...,
#          7674103.06062   ,  6207871.45999392,  9679999.70540996]])

# %%
y = [950, 1300, 800, 1000, 1300]
y
# Out:
# [950, 1300, 800, 1000, 1300]

# %%
ixtx = np.linalg.inv(XTX)

# %%
ixtx
# Out:
# array([[-5.51532691e+07,  1.74531179e+07, -7.81954134e+07, ...,
#         -2.12436688e+08,  1.66992788e+08, -2.44727385e+07],
#        [ 1.27581639e+05,  3.03344948e+05, -9.70622091e+06, ...,
#          8.60732654e+05,  2.05205802e+06,  7.56572645e+06],
#        [ 5.61723147e+07,  1.62555989e+07, -7.79266847e+07, ...,
#         -2.35229177e+08,  7.91411417e+07, -1.00450504e+08],
#        ...,
#        [-3.55147347e+06, -4.72622767e+05, -4.79504712e+06, ...,
#          2.39842950e+05,  2.32981633e+06,  3.48430270e+06],
#        [ 1.55624449e+06,  2.04348036e+05, -1.62329859e+06, ...,
#         -2.65290334e+06,  2.58034972e+06, -1.29599767e+06],
#        [ 7.38561996e+05, -3.09914160e+05, -3.73414885e+05, ...,
#          1.10827291e+05, -1.96931635e+06, -2.99485928e+05]])

# %%
res = ixtx.dot(X.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 res = ixtx.dot(X.T)
#
# ValueError: shapes (20640,20640) and (3,20640) not aligned: 20640 (dim 1) != 3 (dim 0)

# %%
w = res.dot(y)

# %%
w
